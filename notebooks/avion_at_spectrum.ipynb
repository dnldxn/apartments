# %%
from bs4 import BeautifulSoup
from requests import get
import re
from datetime import date, datetime

# %%
# Constants
APARTMENT = 'Avion at Spectrum'
FLOORPLANS = {
    968:    'Refresh1',
    1001:   'Refresh2',
    979:    'Relax1',
    1031:   'Relax2',
    1180:   'Renew'
}
TODAY = str(date.today())
URL = "https://www.avionatspectrum.com/CmsSiteManager/callback.aspx?act=Proxy/GetUnits&available=true&siteid=5952717&bestprice=true&leaseterm=13"


# Scrape
r = get(URL, timeout=20).json()
r['units'][0]
# Out:
# {'amenityList': [{'description': 'Courtyard view',
#    'display': True,
#    'amenityPartnerId': 'S100000282',
#    'partnerPropertyIds': ['4250531'],
#    'displaySequence': 9999,
#    'amenityType': 'UNIT_CUSTOM_AMENITY',
#    'actualName': 'Courtyard view',
#    'name': 'Courtyard view',
#    'id': '20382343'},
#   {'description': 'White Cabinets',
#    'display': True,
#    'amenityPartnerId': 'P000000582',
#    'partnerPropertyIds': ['4250531'],
#    'displaySequence': 9999,
#    'amenityType': 'UNIT_CUSTOM_AMENITY',
#    'actualName': 'White Cabinets',
#    'name': 'White Cabinets',
#    'id': '20382338'}],
#  'hasRentMatrix': True,
#  'unitLeasedStatus': 'Available',
#  'unitOccupancyStatus': 'Vacant',
#  'partnerPropertyId': '4250531',
#  'partnerName': 'OneSite',
#  'internalAvailableDate': '2018-12-22 00:00 -0600',
#  'vacantDate': '2019-01-17 00:00 -0000',
#  'rentModifiedTimestamp': '2019-03-17 15:47 -0500',
#  'numberOfBaths': 1.0,
#  'numberOfBeds': 1,
#  'newAudit': {'createdUserType': 'USER',
#   'modifiedUserType': 'SOURCE',
#   'modifiedId': 219,
#   'createdId': 999123042,
#   'createdTimeStamp': '2019-03-04 23:13 -0600',
#   'modifiedTimeStamp': '2019-03-17 15:47 -0500'},
#  'floorPlanImages': [{'maxWidth': '3000',
#    'maxHeight': '3000',
#    'httpsSrc': 'https://capi.myleasestar.com/v2/dimg/65737632/%s/65737632.jpg',
#    'tag': '3D Furnished',
#    'mediaId': 65737632,
#    'displaySequence': 10,
#    'subtext': '',
#    'src': 'https://capi.myleasestar.com/v2/dimg/65737632/%s/65737632.jpg',
#    'alt': 'Restore2: Beds - 1: Baths - 1: SqFt Range - 795 to 795'},
#   {'maxWidth': '3000',
#    'maxHeight': '3000',
#    'httpsSrc': 'https://capi.myleasestar.com/v2/dimg/65737631/%s/65737631.jpg',
#    'tag': '3D Unfurnished',
#    'mediaId': 65737631,
#    'displaySequence': 20,
#    'subtext': '',
#    'src': 'https://capi.myleasestar.com/v2/dimg/65737631/%s/65737631.jpg',
#    'alt': 'Restore2: Beds - 1: Baths - 1: SqFt Range - 795 to 795'},
#   {'maxWidth': '3000',
#    'maxHeight': '3000',
#    'httpsSrc': 'https://capi.myleasestar.com/v2/dimg/65737630/%s/65737630.jpg',
#    'tag': '2D Diagram',
#    'mediaId': 65737630,
#    'displaySequence': 30,
#    'subtext': '',
#    'src': 'https://capi.myleasestar.com/v2/dimg/65737630/%s/65737630.jpg',
#    'alt': 'Restore2: Beds - 1: Baths - 1: SqFt Range - 795 to 795'}],
#  'entityName': '10107',
#  'active': True,
#  'entityId': 12090836,
#  'propertyId': 5952717,
#  'floorplanId': 7939644,
#  'leaseStatus': 'AVAILABLE_READY',
#  'unitNumber': '10107',
#  'buildingName': 'N/A',
#  'unitPartnerId': '266',
#  'rent': 2053,
#  'floorplanPartnerId': '6',
#  'displayed': True,
#  'squareFeet': 795,
#  'buildingId': 1,
#  'displayOrder': 20,
#  'rentModifiedId': 219,
#  'rentModifiedType': 'SOURCE',
#  'depositInMonths': 500.0,
#  'minLeaseTermInMonth': 13,
#  'floorNumber': 0,
#  'maxLeaseTermInMonth': 13,
#  'name': '10107',
#  'id': 12090836}

# %%
listings = []

units = r['units']

for unit in units:

    data = {}
    if unit['numberOfBeds'] > 1:
        data['unit'] = unit['unitNumber']
        data['size'] = unit['squareFeet']

        floorplan = unit['floorPlanImages'][0].get('alt')
        if floorplan:
            data['floorplan'] = re.sub(':.*', '', floorplan)
        else:
            data['floorplan'] = FLOORPLANS[data['size']]

        data['floor'] = unit['unitNumber'][2]
        data['available_dt'] = re.sub(' .*', '', unit['vacantDate'])
        data['beds'] = unit['numberOfBeds']
        data['baths'] = unit['numberOfBaths']
        
        data['terms'] = []
        data['terms'].append({'k': unit['maxLeaseTermInMonth'], 'v': unit['rent']})

        listings.append(data)


listings
# Out:
# [{'unit': '07316',
#   'size': 1180,
#   'floorplan': 'Renew',
#   'floor': '3',
#   'available_dt': '2019-03-15',
#   'beds': 2,
#   'baths': 2.0,
#   'terms': [{'k': 13, 'v': 2501}]},
#  {'unit': '09213',
#   'size': 968,
#   'floorplan': 'Refresh1',
#   'floor': '2',
#   'available_dt': '2019-04-16',
#   'beds': 2,
#   'baths': 1.0,
#   'terms': [{'k': 13, 'v': 2528}]},
#  {'unit': '02311',
#   'size': 1180,
#   'floorplan': 'Renew',
#   'floor': '3',
#   'available_dt': '2019-04-16',
#   'beds': 2,
#   'baths': 2.0,
#   'terms': [{'k': 13, 'v': 2735}]},
#  {'unit': '02113',
#   'size': 1001,
#   'floorplan': 'Refresh2',
#   'floor': '1',
#   'available_dt': '2019-04-20',
#   'beds': 2,
#   'baths': 1.0,
#   'terms': [{'k': 13, 'v': 2409}]},
#  {'unit': '08208',
#   'size': 1180,
#   'floorplan': 'Renew',
#   'floor': '2',
#   'available_dt': '2019-05-03',
#   'beds': 2,
#   'baths': 2.0,
#   'terms': [{'k': 13, 'v': 2548}]},
#  {'unit': '04201',
#   'size': 979,
#   'floorplan': 'Relax1',
#   'floor': '2',
#   'available_dt': '2019-05-07',
#   'beds': 2,
#   'baths': 2.0,
#   'terms': [{'k': 13, 'v': 2349}]}]
